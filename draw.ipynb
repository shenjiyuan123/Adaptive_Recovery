# %% [markdown]
# # Loss curve

# %%
import pandas as pd
import matplotlib.pyplot as plt


fig = plt.figure(figsize=(18, 6))

file_path = 'assets/mnist_p10.csv'
data = pd.read_csv(file_path)

data_interpolated = data.copy()
data_interpolated['colorful-cherry-19 - Train_loss/Crab'] = data['colorful-cherry-19 - Train_loss/Crab'].interpolate()


######################################################################
ax1 = plt.subplot(1,3,1)

plt.plot(data_interpolated['Step'], data_interpolated['drawn-tree-16 - Train_loss/Retrain'], label='Retrain', marker='o', color='royalblue', linewidth=2, markersize=6)
plt.plot(data_interpolated['Step'], data_interpolated['FedRecover'], label='FedRecover', marker='v', color='crimson', linewidth=2, markersize=6)
plt.plot(data_interpolated['Step'], data_interpolated['lyric-sea-17 - Train_loss/FedEraser'], label='FedEraser', marker='^', color='forestgreen', linewidth=2, markersize=6)
plt.plot(data_interpolated['Step'][5:], data_interpolated['colorful-cherry-19 - Train_loss/Crab'][5:], label='Crab', color='goldenrod', linewidth=3)

original_crab_data = data.dropna(subset=['colorful-cherry-19 - Train_loss/Crab'])
plt.scatter(original_crab_data['Step'][2:], original_crab_data['colorful-cherry-19 - Train_loss/Crab'][2:], color='goldenrod', marker='*', linewidths=2)

plt.xlabel('Steps', fontsize=14)
plt.ylabel('Loss', fontsize=14)
plt.ylim(0, 2.5)
plt.legend(fontsize=12, loc='upper right', frameon=True, shadow=True)
plt.grid(True, which='both', linestyle='-', linewidth=0.75, alpha=0.7)
plt.title('Target clients / Total clients = 10%')

######################################################################
plt.subplot(1,3,2)
file_path = 'assets/mnist_p25.csv'
data = pd.read_csv(file_path)

data_interpolated = data.copy()
data_interpolated['Crab'] = data['Crab'].interpolate()

plt.plot(data_interpolated['Step'], data_interpolated['Retrain'], label='Retrain', marker='.', color='royalblue', linewidth=2, markersize=6)
plt.plot(data_interpolated['Step'], data_interpolated['FedRecover'], label='FedRecover', marker='v', color='crimson', linewidth=2, markersize=6)
plt.plot(data_interpolated['Step'], data_interpolated['FedEraser'], label='FedEraser', marker='^', color='forestgreen', linewidth=2, markersize=6)
plt.plot(data_interpolated['Step'][4:], data_interpolated['Crab'][4:], label='Crab', color='goldenrod', linewidth=3)

original_crab_data = data.dropna(subset=['Crab'])
plt.scatter(original_crab_data['Step'][2:], original_crab_data['Crab'][2:], color='goldenrod', marker='*', linewidths=2)

plt.xlabel('Steps', fontsize=14)
plt.ylabel('Loss', fontsize=14)
plt.ylim(0, 2.5)
plt.legend(fontsize=12, loc='upper right', frameon=True, shadow=True)
plt.grid(True, which='both', linestyle='-', linewidth=0.75, alpha=0.7)
plt.title('Target clients / Total clients = 25%')

######################################################################
plt.subplot(1,3,3)
file_path = 'assets/mnist_p50.csv'
data = pd.read_csv(file_path)

data_interpolated = data.copy()
data_interpolated['Crab'] = data['Crab'].interpolate()

plt.plot(data_interpolated['Step'], data_interpolated['Retrain'], label='Retrain', marker='.', color='royalblue', linewidth=2, markersize=6)
plt.plot(data_interpolated['Step'], data_interpolated['FedRecover'], label='FedRecover', marker='v', color='crimson', linewidth=2, markersize=6)
plt.plot(data_interpolated['Step'], data_interpolated['FedEraser'], label='FedEraser', marker='^', color='forestgreen', linewidth=2, markersize=6)
plt.plot(data_interpolated['Step'][2:], data_interpolated['Crab'][2:], label='Crab', color='goldenrod', linewidth=3)

original_crab_data = data.dropna(subset=['Crab'])
plt.scatter(original_crab_data['Step'][1:], original_crab_data['Crab'][1:], color='goldenrod', marker='*', linewidths=2)

plt.xlabel('Steps', fontsize=14)
plt.ylabel('Loss', fontsize=14)
plt.ylim(0, 2.5)
plt.legend(fontsize=12, loc='upper right', frameon=True, shadow=True)
plt.grid(True, which='both', linestyle='-', linewidth=0.75, alpha=0.7)
plt.title('Target clients / Total clients = 50%')

######################################################################
plt.tight_layout(pad=2.8)
plt.suptitle("MNIST", fontsize=20)
# plt.show()
plt.savefig('assets/mnist_loss_vary3.pdf',bbox_inches='tight',dpi=fig.dpi,pad_inches=0.05)

# %%
import pandas as pd
import matplotlib.pyplot as plt


fig = plt.figure(figsize=(18, 6))

file_path = 'assets/fmnist_p10.csv'
data = pd.read_csv(file_path)

data_interpolated = data.copy()
data_interpolated['Crab'] = data['Crab'].interpolate()


######################################################################
ax1 = plt.subplot(1,3,1)

plt.plot(data_interpolated['Step'], data_interpolated['Retrain'], label='Retrain', marker='o', color='royalblue', linewidth=2, markersize=6)
plt.plot(data_interpolated['Step'], data_interpolated['FedRecover'], label='FedRecover', marker='v', color='crimson', linewidth=2, markersize=6)
plt.plot(data_interpolated['Step'], data_interpolated['FedEraser'], label='FedEraser', marker='^', color='forestgreen', linewidth=2, markersize=6)
plt.plot(data_interpolated['Step'][7:], data_interpolated['Crab'][7:], label='Crab', color='goldenrod', linewidth=3)

original_crab_data = data.dropna(subset=['Crab'])
plt.scatter(original_crab_data['Step'][5:], original_crab_data['Crab'][5:], color='goldenrod', marker='*', linewidths=2)

plt.xlabel('Steps', fontsize=14)
plt.ylabel('Loss', fontsize=14)
plt.ylim(0, 2.5)
plt.legend(fontsize=12, loc='upper right', frameon=True, shadow=True)
plt.grid(True, which='both', linestyle='-', linewidth=0.75, alpha=0.7)
plt.title('Target clients / Total clients = 10%')

######################################################################
plt.subplot(1,3,2)
file_path = 'assets/fmnist_p25.csv'
data = pd.read_csv(file_path)

data_interpolated = data.copy()
data_interpolated['Crab'] = data['Crab'].interpolate()

plt.plot(data_interpolated['Step'], data_interpolated['Retrain'], label='Retrain', marker='.', color='royalblue', linewidth=2, markersize=6)
plt.plot(data_interpolated['Step'], data_interpolated['FedRecover'], label='FedRecover', marker='v', color='crimson', linewidth=2, markersize=6)
plt.plot(data_interpolated['Step'], data_interpolated['FedEraser'], label='FedEraser', marker='^', color='forestgreen', linewidth=2, markersize=6)
plt.plot(data_interpolated['Step'][3:], data_interpolated['Crab'][3:], label='Crab', color='goldenrod', linewidth=3)

original_crab_data = data.dropna(subset=['Crab'])
plt.scatter(original_crab_data['Step'][3:], original_crab_data['Crab'][3:], color='goldenrod', marker='*', linewidths=2)

plt.xlabel('Steps', fontsize=14)
plt.ylabel('Loss', fontsize=14)
plt.ylim(0, 2.5)
plt.legend(fontsize=12, loc='upper right', frameon=True, shadow=True)
plt.grid(True, which='both', linestyle='-', linewidth=0.75, alpha=0.7)
plt.title('Target clients / Total clients = 25%')

######################################################################
plt.subplot(1,3,3)
file_path = 'assets/fmnist_p50.csv'
data = pd.read_csv(file_path)

data_interpolated = data.copy()
data_interpolated['Crab'] = data['Crab'].interpolate()

plt.plot(data_interpolated['Step'], data_interpolated['Retrain'], label='Retrain', marker='.', color='royalblue', linewidth=2, markersize=6)
plt.plot(data_interpolated['Step'], data_interpolated['FedRecover'], label='FedRecover', marker='v', color='crimson', linewidth=2, markersize=6)
plt.plot(data_interpolated['Step'], data_interpolated['FedEraser'], label='FedEraser', marker='^', color='forestgreen', linewidth=2, markersize=6)
plt.plot(data_interpolated['Step'][1:], data_interpolated['Crab'][1:], label='Crab', color='goldenrod', linewidth=3)

original_crab_data = data.dropna(subset=['Crab'])
plt.scatter(original_crab_data['Step'][1:], original_crab_data['Crab'][1:], color='goldenrod', marker='*', linewidths=2)

plt.xlabel('Steps', fontsize=14)
plt.ylabel('Loss', fontsize=14)
plt.ylim(0, 2.5)
plt.legend(fontsize=12, loc='upper right', frameon=True, shadow=True)
plt.grid(True, which='both', linestyle='-', linewidth=0.75, alpha=0.7)
plt.title('Target clients / Total clients = 50%')

######################################################################
plt.tight_layout(pad=2.8)
plt.suptitle("Fashion-MNIST", fontsize=20)
# plt.show()
plt.savefig('assets/fmnist_loss_vary3.pdf',bbox_inches='tight',dpi=fig.dpi,pad_inches=0.05)

# %%
import pandas as pd
import matplotlib.pyplot as plt


fig = plt.figure(figsize=(18, 6))

file_path = 'assets/cifar10_p10.csv'
data = pd.read_csv(file_path)

data_interpolated = data.copy()
data_interpolated['Crab'] = data['Crab'].interpolate()


######################################################################
ax1 = plt.subplot(1,3,1)

plt.plot(data_interpolated['Step'], data_interpolated['Retrain'], label='Retrain', marker='o', color='royalblue', linewidth=2, markersize=6)
plt.plot(data_interpolated['Step'], data_interpolated['FedRecover'], label='FedRecover', marker='v', color='crimson', linewidth=2, markersize=6)
plt.plot(data_interpolated['Step'], data_interpolated['FedEraser'], label='FedEraser', marker='^', color='forestgreen', linewidth=2, markersize=6)
plt.plot(data_interpolated['Step'][7:], data_interpolated['Crab'][7:], label='Crab', color='goldenrod', linewidth=3)

original_crab_data = data.dropna(subset=['Crab'])
plt.scatter(original_crab_data['Step'][2:], original_crab_data['Crab'][2:], color='goldenrod', marker='*', linewidths=2)

plt.xlabel('Steps', fontsize=14)
plt.ylabel('Loss', fontsize=14)
plt.ylim(1.0, 2.75)
plt.legend(fontsize=12, loc='upper right', frameon=True, shadow=True)
plt.grid(True, which='both', linestyle='-', linewidth=0.75, alpha=0.7)
plt.title('Target clients / Total clients = 10%')

######################################################################
plt.subplot(1,3,2)
file_path = 'assets/cifar10_p25.csv'
data = pd.read_csv(file_path)

data_interpolated = data.copy()
data_interpolated['Crab'] = data['Crab'].interpolate()

plt.plot(data_interpolated['Step'], data_interpolated['Retrain'], label='Retrain', marker='.', color='royalblue', linewidth=2, markersize=6)
plt.plot(data_interpolated['Step'], data_interpolated['FedRecover'], label='FedRecover', marker='v', color='crimson', linewidth=2, markersize=6)
plt.plot(data_interpolated['Step'], data_interpolated['FedEraser'], label='FedEraser', marker='^', color='forestgreen', linewidth=2, markersize=6)
plt.plot(data_interpolated['Step'][5:], data_interpolated['Crab'][5:], label='Crab', color='goldenrod', linewidth=3)

original_crab_data = data.dropna(subset=['Crab'])
plt.scatter(original_crab_data['Step'][2:], original_crab_data['Crab'][2:], color='goldenrod', marker='*', linewidths=2)

plt.xlabel('Steps', fontsize=14)
plt.ylabel('Loss', fontsize=14)
plt.ylim(1.0, 2.75)
plt.legend(fontsize=12, loc='upper right', frameon=True, shadow=True)
plt.grid(True, which='both', linestyle='-', linewidth=0.75, alpha=0.7)
plt.title('Target clients / Total clients = 25%')

######################################################################
plt.subplot(1,3,3)
file_path = 'assets/cifar10_p50.csv'
data = pd.read_csv(file_path)

data_interpolated = data.copy()
data_interpolated['Crab'] = data['Crab'].interpolate()

plt.plot(data_interpolated['Step'], data_interpolated['Retrain'], label='Retrain', marker='.', color='royalblue', linewidth=2, markersize=6)
plt.plot(data_interpolated['Step'], data_interpolated['FedRecover'], label='FedRecover', marker='v', color='crimson', linewidth=2, markersize=6)
plt.plot(data_interpolated['Step'], data_interpolated['FedEraser'], label='FedEraser', marker='^', color='forestgreen', linewidth=2, markersize=6)
plt.plot(data_interpolated['Step'], data_interpolated['Crab'], label='Crab', color='goldenrod', linewidth=3)

original_crab_data = data.dropna(subset=['Crab'])
plt.scatter(original_crab_data['Step'], original_crab_data['Crab'], color='goldenrod', marker='*', linewidths=2)

plt.xlabel('Steps', fontsize=14)
plt.ylabel('Loss', fontsize=14)
plt.ylim(1.0, 2.75)
plt.legend(fontsize=12, loc='upper right', frameon=True, shadow=True)
plt.grid(True, which='both', linestyle='-', linewidth=0.75, alpha=0.7)
plt.title('Target clients / Total clients = 50%')

######################################################################
plt.tight_layout(pad=2.8)
plt.suptitle("CIFAR10", fontsize=20)
# plt.show()
plt.savefig('assets/cifar10_loss_vary3.pdf',bbox_inches='tight',dpi=fig.dpi,pad_inches=0.05)

# %% [markdown]
# # Test Accuracy

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker

plt.figure(figsize=(18, 6))

# Adjusting subplot spacing
plt.subplots_adjust(wspace=0.35)

######################################################################
# First subplot
ax1 = plt.subplot(1, 3, 1)
data = [0.9243, 0.9367, 0.9323, 0.8838, 0.9255]
labels = ["FL", "Retrain", "FedEraser", "FedRecover", "Crab"]
bar_width = 0.6
colors = ['#7f7f7f', '#bcbd22', '#17becf', '#1f77b4', '#e377c2']
hatches = ['\\', '.', '-', 'o', '//']

bars = ax1.bar(labels, data, width=bar_width, color=colors, alpha=0.7, edgecolor='black', hatch=hatches)
ax1.axhline(y=data[0], color='r', linestyle='--', linewidth=1.5, alpha=0.7)

for bar in bars:
    yval = bar.get_height()
    ax1.text(bar.get_x() + bar.get_width()/2, yval, round(yval, 4), ha='center', va='bottom')

ax1.grid(axis='y', linestyle='--', alpha=0.7)
ax1.set_ylabel("Test Accuracy", fontsize=12)
ax1.set_xlabel("Target clients / Total clients = 10%", fontsize=12)
ax1.set_ylim(0.4, 1)
ax1.yaxis.set_major_formatter(mticker.PercentFormatter(1))

######################################################################
# Second subplot
ax2 = plt.subplot(1, 3, 2)
data = [0.7994, 0.9278, 0.9199, 0.8814, 0.9032]
labels = ["FL", "Retrain", "FedEraser", "FedRecover", "Crab"]

bars = ax2.bar(labels, data, width=bar_width, color=colors, alpha=0.7, edgecolor='black', hatch=hatches)
ax2.axhline(y=data[0], color='r', linestyle='--', linewidth=1.5, alpha=0.7)

for bar in bars:
    yval = bar.get_height()
    ax2.text(bar.get_x() + bar.get_width()/2, yval, round(yval, 4), ha='center', va='bottom')

ax2.grid(axis='y', linestyle='--', alpha=0.7)
ax2.set_ylabel("Test Accuracy", fontsize=12)
ax2.set_xlabel("Target clients / Total clients = 25%", fontsize=12)
ax2.set_ylim(0.4, 1)
ax2.yaxis.set_major_formatter(mticker.PercentFormatter(1))

######################################################################
# Third subplot
ax3 = plt.subplot(1, 3, 3)
data = [0.4669, 0.9328, 0.8931, 0.8464, 0.8811]
labels = ["FL", "Retrain", "FedEraser", "FedRecover", "Crab"]

bars = ax3.bar(labels, data, width=bar_width, color=colors, alpha=0.7, edgecolor='black', hatch=hatches)
ax3.axhline(y=data[0], color='r', linestyle='--', linewidth=1.5, alpha=0.7)

for bar in bars:
    yval = bar.get_height()
    ax3.text(bar.get_x() + bar.get_width()/2, yval, round(yval, 4), ha='center', va='bottom')

ax3.grid(axis='y', linestyle='--', alpha=0.7)
ax3.set_ylabel("Test Accuracy", fontsize=12)
ax3.set_xlabel("Target clients / Total clients = 50%", fontsize=12)
ax3.set_ylim(0.4, 1)
ax3.yaxis.set_major_formatter(mticker.PercentFormatter(1))

######################################################################
# plt.suptitle("Backdoor Attack on MNIST", fontsize=14)
plt.tight_layout()
# plt.show()
plt.savefig('assets/mnist_test_accuracy2.pdf')

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker

plt.figure(figsize=(12, 6))

# Adjusting subplot spacing
plt.subplots_adjust(wspace=0.35)

######################################################################
# First subplot
ax1 = plt.subplot(1, 2, 1)
data = [0.3592, 0.8525, 0.8342, 0.7045, 0.7897]
labels = ["FL", "Retrain", "FedEraser", "FedRecover", "Crab"]
bar_width = 0.6
colors = ['#7f7f7f', '#bcbd22', '#17becf', '#1f77b4', '#e377c2']
hatches = ['\\', '.', '-', 'o', '//']

bars = ax1.bar(labels, data, width=bar_width, color=colors, alpha=0.7, edgecolor='black', hatch=hatches)

ax1.axhline(y=data[0], color='r', linestyle='--', linewidth=1.5, alpha=0.7)

for bar in bars:
    yval = bar.get_height()
    ax1.text(bar.get_x() + bar.get_width()/2, yval, round(yval, 4), ha='center', va='bottom')

ax1.grid(axis='y', linestyle='--', alpha=0.7)
ax1.set_ylabel("Test Accuracy", fontsize=12)
ax1.set_xlabel("Fashion-MNIST \n Target clients / Total clients = 50%", fontsize=12)
ax1.set_ylim(0.2, 0.9)
ax1.yaxis.set_major_formatter(mticker.PercentFormatter(1))

######################################################################
# Second subplot
ax2 = plt.subplot(1, 2, 2)
data = [0.1108, 0.5535, 0.5321, 0.3243, 0.4661]
labels = ["FL", "Retrain", "FedEraser", "FedRecover", "Crab"]

bars = ax2.bar(labels, data, width=bar_width, color=colors, alpha=0.7, edgecolor='black', hatch=hatches)
ax2.axhline(y=data[0], color='r', linestyle='--', linewidth=1.5, alpha=0.7)

for bar in bars:
    yval = bar.get_height()
    ax2.text(bar.get_x() + bar.get_width()/2, yval, round(yval, 4), ha='center', va='bottom')

ax2.grid(axis='y', linestyle='--', alpha=0.7)
ax2.set_ylabel("Test Accuracy", fontsize=12)
ax2.set_xlabel("CIFAR-10 \n Target clients / Total clients = 50%", fontsize=12)
ax2.set_ylim(0, 0.6)
ax2.yaxis.set_major_formatter(mticker.PercentFormatter(1))

######################################################################

# plt.suptitle("Backdoor Attack on MNIST", fontsize=14)
plt.tight_layout()
# plt.show()
plt.savefig('assets/fmnist_cifar10_test_accuracy2.pdf')

# %% [markdown]
# # Trim

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker

plt.figure(figsize=(18, 6))

# Adjusting subplot spacing
plt.subplots_adjust(wspace=0.35)

######################################################################
# First subplot
ax1 = plt.subplot(1, 3, 1)
data = [0.6174, 0.9280, 0.9318, 0.8632, 0.8943]
labels = ["FL", "Retrain", "FedEraser", "FedRecover", "Crab"]
bar_width = 0.6
colors = ['#7f7f7f', '#bcbd22', '#17becf', '#1f77b4', '#e377c2']
hatches = ['\\', '.', '-', 'o', '//']

bars = ax1.bar(labels, data, width=bar_width, color=colors, alpha=0.7, edgecolor='black', hatch=hatches)

ax1.axhline(y=data[0], color='r', linestyle='--', linewidth=1.5, alpha=0.7)

for bar in bars:
    yval = bar.get_height()
    ax1.text(bar.get_x() + bar.get_width()/2, yval, round(yval, 4), ha='center', va='bottom')

ax1.grid(axis='y', linestyle='--', alpha=0.7)
ax1.set_ylabel("Test Accuracy", fontsize=12)
ax1.set_xlabel("MNIST", fontsize=12)
ax1.set_ylim(0.4, 1)
ax1.yaxis.set_major_formatter(mticker.PercentFormatter(1))

######################################################################
# Second subplot
ax2 = plt.subplot(1, 3, 2)
data = [0.2643, 0.8962, 0.8917, 0.7006, 0.8767]
labels = ["FL", "Retrain", "FedEraser", "FedRecover", "Crab"]

bars = ax2.bar(labels, data, width=bar_width, color=colors, alpha=0.7, edgecolor='black', hatch=hatches)
ax2.axhline(y=data[0], color='r', linestyle='--', linewidth=1.5, alpha=0.7)

for bar in bars:
    yval = bar.get_height()
    ax2.text(bar.get_x() + bar.get_width()/2, yval, round(yval, 4), ha='center', va='bottom')

ax2.grid(axis='y', linestyle='--', alpha=0.7)
ax2.set_ylabel("Test Accuracy", fontsize=12)
ax2.set_xlabel("Fashion-MNIST", fontsize=12)
ax2.set_ylim(0, 1)
ax2.yaxis.set_major_formatter(mticker.PercentFormatter(1))

######################################################################
# Third subplot
ax3 = plt.subplot(1, 3, 3)
data = [0.1083, 0.6454, 0.6609, 0.2933, 0.6307]
labels = ["FL", "Retrain", "FedEraser", "FedRecover", "Crab"]

bars = ax3.bar(labels, data, width=bar_width, color=colors, alpha=0.7, edgecolor='black', hatch=hatches)
ax3.axhline(y=data[0], color='r', linestyle='--', linewidth=1.5, alpha=0.7)

for bar in bars:
    yval = bar.get_height()
    ax3.text(bar.get_x() + bar.get_width()/2, yval, round(yval, 4), ha='center', va='bottom')

ax3.grid(axis='y', linestyle='--', alpha=0.7)
ax3.set_ylabel("Test Accuracy", fontsize=12)
ax3.set_xlabel("CIFAR-10", fontsize=12)
ax3.set_ylim(0, 0.7)
ax3.yaxis.set_major_formatter(mticker.PercentFormatter(1))

######################################################################
# plt.suptitle("Trim Attack", fontsize=14)
plt.tight_layout()
# plt.show()
plt.savefig('assets/trim_attack_test_accuracy2.pdf')

# %% [markdown]
# # Backdoor

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker

plt.figure(figsize=(18, 6))
plt.subplots_adjust(wspace=0.35)


######################################################################
# first
labels = ["FL", "Retrain", "FedEraser", "FedRecover", "Crab"]
bar_width = 0.6
colors = ['#7f7f7f', '#bcbd22', '#17becf', '#1f77b4', '#e377c2']
mia = [0.9449, 0.3496, 0.3934, 0.5197, 0.3797]  # Bar chart data for MIA
asr = [0.4275, 0.1064, 0.0764, 0.1068, 0.0984]  # Line chart data for ASR

ax1 = plt.subplot(1,3,1)
hatches = ['\\', '.', '-', 'o', '//']

# Bar chart for MIA
bars = ax1.bar(labels, mia, color=colors, alpha=0.7, label='MIA', width=bar_width, edgecolor='black', hatch=hatches)

for bar in bars:
    yval = bar.get_height()
    ax1.text(bar.get_x() + bar.get_width()/2, yval, round(yval, 4), ha='center', va='bottom')

# Make the y-axis label for MIA
ax1.set_ylabel('MISR', fontsize=12)
ax1.tick_params('y')
ax1.set_ylim(0,1)

# Line chart for ASR
ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
ax2.plot(labels, asr, linestyle='--', marker='o', label='ASR', c='black')
ax2.set_ylabel('ASR', fontsize=12)
ax2.tick_params('y')
ax2.set_ylim(0,0.5)
ax2.grid(axis='y', linestyle='--', alpha=0.7)

ax1.set_xlabel('MNIST', fontsize=12)
ax1.yaxis.set_major_formatter(mticker.PercentFormatter(1))
######################################################################
# second
labels = ["FL", "Retrain", "FedEraser", "FedRecover", "Crab"]
bar_width = 0.6
mia = [0.9874, 0.7929, 0.7780, 0.8385, 0.8340]  # Bar chart data for MIA
asr = [0.3352, 0.0765, 0.0997, 0.1128, 0.0984]  # Line chart data for ASR

ax1 = plt.subplot(1,3,2)

# Bar chart for MIA
bars = ax1.bar(labels, mia, color=colors, alpha=0.7, label='MIA', width=bar_width, edgecolor='black', hatch=hatches)

for i, bar in enumerate(bars):
    yval = bar.get_height()
    if i == 0:
        ax1.text(bar.get_x() + bar.get_width()/2, 0.95*yval, round(yval, 4), ha='center', va='bottom')
    else:
        ax1.text(bar.get_x() + bar.get_width()/2, yval, round(yval, 4), ha='center', va='bottom')

# Make the y-axis label for MIA
ax1.set_ylabel('MISR', fontsize=12)
ax1.tick_params('y')
ax1.set_ylim(0.5,1)

# Line chart for ASR
ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
ax2.plot(labels, asr, linestyle='--', marker='o', label='ASR', c='black')
ax2.set_ylabel('ASR', fontsize=12)
ax2.tick_params('y')
ax2.set_ylim(0,0.5)
ax2.grid(axis='y', linestyle='--', alpha=0.7)

ax1.set_xlabel('Fashion-MNIST', fontsize=12)
ax1.yaxis.set_major_formatter(mticker.PercentFormatter(1))
######################################################################
# third
labels = ["FL", "Retrain", "FedEraser", "FedRecover", "Crab"]
bar_width = 0.6
mia = [0.9863, 0.9156, 0.8810, 0.9156, 0.9056]  # Bar chart data for MIA
asr = [0.3621, 0.0981, 0.0998, 0.0994, 0.0964]  # Line chart data for ASR

ax1 = plt.subplot(1,3,3)

# Bar chart for MIA
bars = ax1.bar(labels, mia, color=colors, alpha=0.7, label='MIA', width=bar_width, edgecolor='black', hatch=hatches)

for i, bar in enumerate(bars):
    yval = bar.get_height()
    if i == 0:
        print('third')
        ax1.text(bar.get_x() + bar.get_width()/2, 0.95*yval, round(yval, 4), ha='center', va='bottom')
    else:
        ax1.text(bar.get_x() + bar.get_width()/2, yval, round(yval, 4), ha='center', va='bottom')

# Make the y-axis label for MIA
ax1.set_ylabel('MISR', fontsize=12)
ax1.tick_params('y')
ax1.set_ylim(0.5,1)

# Line chart for ASR
ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
ax2.plot(labels, asr, linestyle='--', marker='o', label='ASR', c='black')
ax2.set_ylabel('ASR', fontsize=12)
ax2.tick_params('y')
ax2.set_ylim(0,0.5)
ax2.grid(axis='y', linestyle='--', alpha=0.7)

ax1.set_xlabel('CIFAR-10', fontsize=12)
ax1.yaxis.set_major_formatter(mticker.PercentFormatter(1))
######################################################################


# plt.suptitle('MIA and ASR Comparison')
# plt.show()
plt.tight_layout()
plt.savefig('assets/backdoor_asr2.pdf')
# Out:
# third

# %% [markdown]
# # Analysis

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker

plt.figure(figsize=(10, 5))
plt.subplots_adjust(wspace=0.35)


######################################################################
# first
labels = ['0.3', '0.4', '0.5', '0.6', '0.7', '0.8', '0.9']
bar_width = 0.6
colors = ['#7f7f7f', '#bcbd22', '#17becf', '#1f77b4', '#e377c2',   '#2f57c4', '#8c37e4']
ta = [0.7398, 0.7630, 0.7721, 0.7851, 0.7811, 0.7989, 0.8062]  # Bar chart data for MIA
asr = [0.1296, 0.1010, 0.0994, 0.0998, 0.0997, 0.0997, 0.1003]  # Line chart data for ASR

ax1 = plt.subplot(1,2,1)
hatches = ['\\', '.', '-', 'o', '//', '*']

# Bar chart for MIA
bars = ax1.bar(labels, ta, color=colors, alpha=0.7, label='TA', width=bar_width, edgecolor='black')

for bar in bars:
    yval = bar.get_height()
    ax1.text(bar.get_x() + bar.get_width()/2, yval, round(yval, 4), ha='center', va='bottom')

# Make the y-axis label for MIA
ax1.set_ylabel('Test Accuracy', fontsize=12)
ax1.tick_params('y')
ax1.set_ylim(0.6,0.9)

# Line chart for ASR
ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
ax2.plot(labels, asr, linestyle='--', marker='o', label='ASR', c='black')
ax2.set_ylabel('ASR', fontsize=12)
ax2.tick_params('y')
ax2.set_ylim(0,0.4)
ax2.grid(axis='y', linestyle='--', alpha=0.7)

ax1.set_xlabel('Ratio', fontsize=12)
ax1.set_title('Round Selection', fontsize=12)
ax1.yaxis.set_major_formatter(mticker.PercentFormatter(1))
######################################################################
# second
labels = ['0.5', '0.6', '0.7', '0.8', '0.9', '1.0']
bar_width = 0.6
ta = [0.7321, 0.7509, 0.7721, 0.7644, 0.7687, 0.7688]  # Bar chart data for MIA
asr = [0.1001, 0.0991, 0.0994, 0.0996, 0.1003, 0.1002]  # Line chart data for ASR

ax1 = plt.subplot(1,2,2)

# Bar chart for MIA
bars = ax1.bar(labels, ta, color=colors, alpha=0.7, label='TA', width=bar_width, edgecolor='black')

for i, bar in enumerate(bars):
    yval = bar.get_height()
    ax1.text(bar.get_x() + bar.get_width()/2, yval, round(yval, 4), ha='center', va='bottom')

# Make the y-axis label for MIA
ax1.set_ylabel('Test Accuracy', fontsize=12)
ax1.tick_params('y')
ax1.set_ylim(0.6,0.9)

# Line chart for ASR
ax2 = ax1.twinx()  # instantiate a second axes that shares the same x-axis
ax2.plot(labels, asr, linestyle='--', marker='o', label='ASR', c='black')
ax2.set_ylabel('ASR', fontsize=12)
ax2.tick_params('y')
ax2.set_ylim(0,0.4)
ax2.grid(axis='y', linestyle='--', alpha=0.7)

ax1.set_xlabel('Ratio', fontsize=12)
ax1.set_title('Client Selection', fontsize=12)
ax1.yaxis.set_major_formatter(mticker.PercentFormatter(1))
######################################################################


# plt.suptitle('MIA and ASR Comparison')
# plt.show()
plt.tight_layout()
plt.savefig('assets/analysis_select2.pdf')

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as mticker

plt.figure(figsize=(6, 5))
# plt.subplots_adjust(wspace=0.35)

######################################################################
# first
labels = ['0.1', '0.3', '0.5', '0.7', '0.9']
bar_width = 0.6
colors = ['#7f7f7f', '#bcbd22', '#17becf', '#1f77b4', '#e377c2',   '#2f57c4', '#8c37e4']
less_ta = [0.7523, 0.7408, 0.7145, 0.7088, 0.6911]  
ta = [0.81332, 0.8048, 0.7824, 0.7542, 0.7289]  
taeraser = [0.8342, 0.8328, 0.8056, 0.7739, 0.7360]  

ax1 = plt.subplot(1,1,1)

ax1.plot(labels, less_ta, linestyle='--', marker='o', label=r'$P=0.3, X=0.5$', c='#2f57c4', alpha=0.8)
ax1.plot(labels, ta, linestyle='--', marker='o', label=r'$P=0.6, X=0.7$', c='#8c37e4', alpha=0.9, markersize=7)
ax1.plot(labels, taeraser, linestyle='--', marker='o', label=r'$P=1.0, X=1.0$', alpha=0.8, c='grey')
ax1.legend(fontsize=12, loc='upper right', frameon=True, shadow=True)
ax1.set_ylabel('Test Accuracy', fontsize=12)
ax1.tick_params('y')
ax1.set_ylim(0.6,1)
ax1.grid(True, which='both', linestyle='-', linewidth=0.75, alpha=0.7)

ax1.set_xlabel(r'Sensitivity Bound $\beta$', fontsize=12)
ax1.set_title('Adaptive Rollback', fontsize=12)
ax1.yaxis.set_major_formatter(mticker.PercentFormatter(1))

plt.tight_layout()
plt.savefig('assets/Adaptive_Rollback.pdf')
